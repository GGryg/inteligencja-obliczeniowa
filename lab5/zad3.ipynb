# %%
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import pandas as pd
import graphviz

df = pd.read_csv("iris.csv")
(train_set, test_set) = train_test_split(df.values, train_size=0.7, random_state=278839)

# print(test_set)

test_class = test_set[:, 4]
test_input = test_set[:, 0:4]
train_class = train_set[:, 4]
train_input = train_set[:, 0:4]

# %% [markdown]
# Importy i przygotowanie danych

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(train_input, train_class)

# %% [markdown]
# Drzewo decyzyjne

# %%
# z użyciem clf.score
print(clf.score(test_input, test_class) * 100)

tree.plot_tree(clf)

# z użyciem clf.predict
good_predictions = 0
leng = test_set.shape[0]

for i in range(leng):
    if clf.predict([test_input[i]]) == test_class[i]:
        good_predictions += 1

print(good_predictions)
print(good_predictions/leng*100, "%")
# Out:
# 93.33333333333333
# 42
# 93.33333333333333 %

# %% [markdown]
# Wyświetlnie dokładności i drzewka

# %%
y_true = test_class
y_pred = clf.predict(test_input)

print(confusion_matrix(y_true, y_pred))
# Out:
# [[16  0  0]
#  [ 0 14  2]
#  [ 0  1 12]]

# %% [markdown]
# Wyświetlenie macierzy błędu

# %% [markdown]
# ## Podsumowanie
# Daje dokładność taką samą jak w przypadku własnego drzewka 93.(3)%, ale z powodu random_state
