# %%
import snscrape.modules.twitter as gimmieTweets

query = "#pogrom"

tweets_list = []

for i, tweet in enumerate(gimmieTweets.TwitterSearchScraper(query).get_items()):
    if i > 100:
        break
    tweets_list.append(tweet)

for tweet in tweets_list:
    print(tweet.content)
# Out:
# SuperCum Jana Pawła II w Reykjaviku #ImolaGP #Pogrom https://t.co/GtPDjLRpTk
# @ccdoire Maybe some of the #Dublin #pogrom ists feel pretty slimey as they should hence the insults.
#  The #workingclass has the power and objective interest not only to stop the #racists &amp; #Fascists  but also to overturn the whole #capitalist system that spawns these vermin!
# #EthnicCleansing in #Manipur State of India in progress - #PrimeMinister_Modi is repeating the #Pogrom he presided over in #Gujarat_2002
# @freedomhouse @UN
# @TomaszGraczyk10 @kaczor_danuta Ty tak serio? A to nie czasami Twój ukochany Błaszczak występował z Kamińskim na tle pokazu slajdów z pikselozą? Ja nie widziałem większej kompromitacji! To rozjechało wszystko!
# #KaczkaPrzegina
# #KongresTrutni
# #Pogrom
# #CiUL
# #PiStoZŁO
# A czy na ostatnim ich kongresie nie było o  #Pogrom… ośmieszyliśmy ta koncepcje i wczoraj ruszyli z #OstatniaKonwencjaPiS z nowym niby przesłaniem. Coś im nie idzie. https://t.co/ZgtIVFqQfH
# ...

# %%
import snscrape.modules.twitter as gimmieTweets

query = "#pogrom  near:'Gdańsk' "

tweets_list = []

for i, tweet in enumerate(gimmieTweets.TwitterSearchScraper(query).get_items()):
    if i > 100:
        break
    tweets_list.append(tweet)

for tweet in tweets_list:
    print(tweet.content)
# Out:
# SuperCum Jana Pawła II w Reykjaviku #ImolaGP #Pogrom https://t.co/GtPDjLRpTk
# @ccdoire Maybe some of the #Dublin #pogrom ists feel pretty slimey as they should hence the insults.
#  The #workingclass has the power and objective interest not only to stop the #racists &amp; #Fascists  but also to overturn the whole #capitalist system that spawns these vermin!
# #EthnicCleansing in #Manipur State of India in progress - #PrimeMinister_Modi is repeating the #Pogrom he presided over in #Gujarat_2002
# @freedomhouse @UN
# @TomaszGraczyk10 @kaczor_danuta Ty tak serio? A to nie czasami Twój ukochany Błaszczak występował z Kamińskim na tle pokazu slajdów z pikselozą? Ja nie widziałem większej kompromitacji! To rozjechało wszystko!
# #KaczkaPrzegina
# #KongresTrutni
# #Pogrom
# #CiUL
# #PiStoZŁO
# A czy na ostatnim ich kongresie nie było o  #Pogrom… ośmieszyliśmy ta koncepcje i wczoraj ruszyli z #OstatniaKonwencjaPiS z nowym niby przesłaniem. Coś im nie idzie. https://t.co/ZgtIVFqQfH
# ...
